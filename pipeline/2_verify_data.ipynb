# %% [markdown]
# # Verify the quality of the data

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
from tools.audio_processing import process_samples

root_path = "/Users/jackcdawson/Desktop/dev/sample_identifier/data"

process_samples(root_path)
# Out:
# Processing samples:   4%|▍         | 829/20452 [00:17<08:54, 36.72it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=816
#   warnings.warn(
# Processing samples:   5%|▌         | 1035/20452 [00:20<06:38, 48.69it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=764
#   warnings.warn(
# Processing samples:   8%|▊         | 1579/20452 [00:28<03:12, 98.00it/s] /opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=834
#   warnings.warn(
# Processing samples:  15%|█▍        | 2970/20452 [00:52<04:57, 58.67it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=737
#   warnings.warn(
# Processing samples:  15%|█▍        | 2985/20452 [00:52<04:47, 60.76it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=656
#   warnings.warn(
# Processing samples:  16%|█▌        | 3319/20452 [00:58<05:48, 49.17it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=608
#   warnings.warn(
# Processing samples:  18%|█▊        | 3775/20452 [01:06<05:31, 50.29it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=735
#   warnings.warn(
# Processing samples:  19%|█▉        | 3917/20452 [01:09<04:30, 61.02it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=934
#   warnings.warn(
# Processing samples:  22%|██▏       | 4488/20452 [01:21<05:45, 46.15it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=635
#   warnings.warn(
# Processing samples:  25%|██▍       | 5103/20452 [01:31<03:23, 75.38it/s] /opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=716
#   warnings.warn(
# Processing samples:  42%|████▏     | 8678/20452 [02:35<03:09, 62.00it/s] /opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=943
#   warnings.warn(
# Processing samples:  50%|█████     | 10325/20452 [03:03<03:34, 47.30it/s]/opt/anaconda3/lib/python3.13/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=998
#   warnings.warn(
# Processing samples:  60%|██████    | 12347/20452 [03:44<02:15, 59.85it/s]
